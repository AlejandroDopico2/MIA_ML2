# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np 
from plotly.subplots import make_subplots
import plotly.graph_objects as go
df = pd.read_csv('air.csv')

# get months and day of the week
df['Month'] = df.Date.map(lambda x: int(x.split('/')[1]))
df['Season'] = (df.Month % 12)//3
df['Time'] = (df.Time.map(lambda x: x.split(':')[0]).astype(int)/24)*2*np.pi
# df['cos(t)'] = df.Time.map(np.cos)
# df['sin(t)'] = df.Time.map(np.sin)

# split target and features 
targets = df['T']
inputs = df.drop(['T', 'Date', 'Time'], axis=1)
inputs
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0        2.6       1360.0     150.0      11.9         1046.0    166.0
# 1        2.0       1292.0     112.0       9.4          955.0    103.0
# 2        2.2       1402.0      88.0       9.0          939.0    131.0
# 3        2.2       1376.0      80.0       9.2          948.0    172.0
# 4        1.6       1272.0      51.0       6.5          836.0    131.0
# ...      ...          ...       ...       ...            ...      ...
# 9352     3.1       1314.0    -200.0      13.5         1101.0    472.0
# 9353     2.4       1163.0    -200.0      11.4         1027.0    353.0
# 9354     2.4       1142.0    -200.0      12.4         1063.0    293.0
# 9355     2.1       1003.0    -200.0       9.5          961.0    235.0
# 9356     2.2       1071.0    -200.0      11.9         1047.0    265.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH      AH  Month  \
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
len(inputs.columns)
# Out:
# 14

# %%
fig = make_subplots(rows=3, cols=5)
for col in inputs.columns:
    fig.add_trace(go.Histogram(inputs[col].values))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [70], line 3
#       1 fig = make_subplots(rows=3, cols=5)
#       2 for col in inputs.columns:
# ----> 3     fig.add_trace(go.Histogram(inputs[col].values))
#
# ...
